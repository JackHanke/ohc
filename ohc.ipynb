# %%
t = var('t')
def lambda_equation(n):
    val = 0
    for k in range(n):
        val += (t**k) / factorial(k)
    return e ** t - (t**n)/factorial(n-1) - val

for n in range(16,17):
    f = lambda_equation(n)
    print(f)
    ans = find_root(f, 20, 22)
    print(ans)
    print(ans*(2**12)/3)
# Out:
# -1/1307674368000*t^16 - 1/1307674368000*t^15 - 1/87178291200*t^14 - 1/6227020800*t^13 - 1/479001600*t^12 - 1/39916800*t^11 - 1/3628800*t^10 - 1/362880*t^9 - 1/40320*t^8 - 1/5040*t^7 - 1/720*t^6 - 1/120*t^5 - 1/24*t^4 - 1/6*t^3 - 1/2*t^2 - t + e^t - 1
# 20.752844842827677
# 28334.55082540739

# %%
t = var('t')
def Lambda_equation(n, m=3, p=2**(-12)):
    val = 0
    for k in range(n):
        val += (p**k) * binomial(m*t, k)
    val *= (1-p)**(m*t - n +1)
    return (1-val)/t

for n in range(16, 17):
    f = Lambda_equation(n)
    print(f)
    # ans = find_root(f, 20, 22)
    ans = find_local_maximum(f, 28334, 28337)
    print(ans)
    # print(ans*(2**12)/3)
# Out:
# -1/8246934723722713521037008091578022233305475862379904343474176000*(((3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(3*t - 10)*(3*t - 11)*(3*t - 13)*(3*t - 14)*(t - 1)*(t - 2)*(t - 3)*(t - 4)*t + 61440*(3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(3*t - 10)*(3*t - 11)*(3*t - 13)*(t - 1)*(t - 2)*(t - 3)*(t - 4)*t + 3523215360*(3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(3*t - 10)*(3*t - 11)*(t - 1)*(t - 2)*(t - 3)*(t - 4)*t + 62534723829760*(3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(3*t - 10)*(3*t - 11)*(t - 1)*(t - 2)*(t - 3)*t + 3073706745680363520*(3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(3*t - 10)*(t - 1)*(t - 2)*(t - 3)*t + 138488931133374458757120*(3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(t - 1)*(t - 2)*(t - 3)*t + 1890835539741005943563878400*(3*t - 1)*(3*t - 2)*(3*t - 4)*(3*t - 5)*(3*t - 7)*(3*t - 8)*(t - 1)*(t - 2)*t + 69703761337012443103538813337600*(3*t - 1)*(3*t - 2)*(3*t 
# ...
